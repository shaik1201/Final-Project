# %%
import pandas as pd
df = pd.read_csv('Jobs_Indeed.csv')
df.head(15)
# Out:
#                                                 title            job_id  \
# 0                        Business Application Analyst  efa2ff88f0ba1b24
# 1                                   Game Data Analyst  37fbaa8d1676bf08
# 2                                        Data Analyst  7712bc50313b655c
# 3     Staff Frontend Engineer - Singularity Data lake  17618e67616bdfee
# 4                             SRH Programme Associate  38edd0c36e928563
# 5                                Product Data Analyst  16ae2eff8d6ca11e
# 6                     BI Data Analyst עבור חברה יציבה  99c2f88b10a02439
# 7                                      People Analyst  194a7424422a13b6
# 8                     לארגון מוביל בת"א, Data Analyst  0dd7d079e88bf62c
# 9   2024 Corporate & Investment Bank - Investment ...  0ff5dde47aaba3df
# 10                            AI/Data Product Manager  32fe38d731f88f93
# 11         לסטארט אפ בתל אביב Fraud Operation Analyst  b818635dbe600f0a
# ...
